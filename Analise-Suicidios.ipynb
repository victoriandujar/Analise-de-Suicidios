# %%
import pandas as pd
import seaborn as sb
low_memory=False
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
filename = 'suicidios.csv'
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (27820, 12)

# %%
df.sample(10)
# Out:
#                    country  year     sex          age  suicides_no  \
# 25496  Trinidad and Tobago  2000  female    75+ years            5
# 26933        United States  1992    male  55-74 years         4818
# 12396              Ireland  2013  female  25-34 years           24
# 17532          New Zealand  1992    male  15-24 years          112
# 5392                 Chile  1995  female  35-54 years           35
# 23984            Sri Lanka  2001    male    75+ years          162
# 19530             Portugal  1999    male  15-24 years           21
# 15494           Luxembourg  2000  female  15-24 years            1
# 21010   Russian Federation  1995    male    75+ years         1182
# 10534              Grenada  2002    male  35-54 years            0
#
#        population  suicides/100k pop             country-year  HDI for year  \
# 25496       19412              25.76  Trinidad and Tobago2000         0.717
# 26933    18038900              26.71        United States1992           NaN
# 12396      366261               6.55              Ireland2013         0.912
# 17532      284800              39.33          New Zealand1992           NaN
# 5392      1697961               2.06                Chile1995         0.723
# 23984      204801              79.10            Sri Lanka2001           NaN
# 19530      769488               2.73             Portugal1999           NaN
# 15494       24072               4.15           Luxembourg2000         0.851
# 21010     1258900              93.89   Russian Federation1995           NaN
# 10534        9549               0.00              Grenada2002           NaN
#
#        gdp_for_year ($)   gdp_per_capita ($)       generation
# 25496      8,154,338,233                6920  G.I. Generation
# 26933  6,539,299,000,000               27760           Silent
# 12396    239,389,340,720               56628       Millenials
# 17532     41,636,005,955               12868     Generation X
# 5392      73,447,063,319                5695          Boomers
# 23984     15,749,753,805                 912           Silent
# 19530    127,465,545,493               13180     Generation X
# 15494     21,263,514,833               51841     Generation X
# 21010    395,531,066,563                2844  G.I. Generation
# 10534        540,336,926                5879          Boomers

# %%
df.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        HDI for year  gdp_per_capita ($)
# count   8364.000000        27820.000000
# mean       0.776601        16866.464414
# std        0.093367        18887.576472
# min        0.483000          251.000000
# 25%        0.713000         3447.000000
# 50%        0.779000         9372.000000
# 75%        0.855000        24874.000000
# max        0.944000       126352.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
# country               27820 non-null object
# year                  27820 non-null int64
# sex                   27820 non-null object
# age                   27820 non-null object
# suicides_no           27820 non-null int64
# population            27820 non-null int64
# suicides/100k pop     27820 non-null float64
# country-year          27820 non-null object
# HDI for year          8364 non-null float64
#  gdp_for_year ($)     27820 non-null object
# gdp_per_capita ($)    27820 non-null int64
# generation            27820 non-null object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 1.9+ MB

# %%
df.groupby('country').size().sort_values().plot(kind='barh')
